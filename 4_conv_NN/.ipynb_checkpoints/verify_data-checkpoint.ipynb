# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
train = np.load('train.npy')/255.0
test = np.load('test.npy')/255.0
label = np.load('label.npy')
print(train.shape)
print(test.shape)
print(label.shape)
# Out:
# (25000, 64, 64)
# (12500, 64, 64)
# (25000,)

# %%
np.count_nonzero(label)
# Out:
# 12500

# %%
i = 0
image = train[i]
res = label[i]

# %%
image
# Out:
# array([[ 0.05882353,  0.0627451 ,  0.07058824, ...,  0.76862746,
#          0.80784315,  0.76078433],
#        [ 0.05490196,  0.0627451 ,  0.0627451 , ...,  0.80784315,
#          0.78431374,  0.76078433],
#        [ 0.07450981,  0.07058824,  0.05882353, ...,  0.81568629,
#          0.68627453,  0.74117649],
#        ...,
#        [ 0.27843139,  0.34117648,  0.31764707, ...,  0.33725491,
#          0.3882353 ,  0.40392157],
#        [ 0.3137255 ,  0.3137255 ,  0.33725491, ...,  0.39215687,
#          0.43529412,  0.47843137],
#        [ 0.32549021,  0.30980393,  0.30588236, ...,  0.39607844,
#          0.48235294,  0.41568628]], dtype=float32)

# %%
res
# Out:
# 1

# %%
label
# Out:
# array([1, 0, 1, ..., 1, 0, 0], dtype=uint8)

# %%
imgplot = plt.imshow(image)

# %%
import six.moves.cPickle as pickle
import gzip
import os
import sys

dataset = '../data/MNIST/mnist.pkl.gz'

with gzip.open(dataset, 'rb') as f:
        try:
            train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
        except:
            train_set, valid_set, test_set = pickle.load(f)

# %%
train_set_x , train_set_y = train_set
train_set_y
# Out:
# array([5, 0, 4, ..., 8, 4, 8])

# %%
train_set_x =train_set_x.reshape(50000,28,28)

# %%
image = train_set_x[12]
imgplot = plt.imshow(image)

# %%
# Out:
# 0.99609375
